# %%
from decouple import config

# %%
assert config("ALPHA_VANTAGE_API_KEY", default=None, cast=str) is not None

# %%
ALPHA_VANTAGE_API_KEY = config("ALPHA_VANTAGE_API_KEY", default=None, cast=str)

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key


api_key = ALPHA_VANTAGE_API_KEY

params = {
    "api_key": ALPHA_VANTAGE_API_KEY,
    "ticker": "AAPL",
    "function": "TIME_SERIES_INTRADAY"
}

url = 'https://www.alphavantage.co/query?function={function}&symbol={ticker}&interval=5min&apikey={api_key}'.format(
    **params
)
r = requests.get(url)
data = r.json()

# %%
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (5min)'])

# %%
import pandas as pd

# Load the JSON data into a pandas DataFrame
df = pd.json_normalize(data)

# Display the DataFrame
display(df)
# Out:
#                             Meta Data.1. Information Meta Data.2. Symbol  \
# 0  Intraday (5min) open, high, low, close prices ...                AAPL
#
#   Meta Data.3. Last Refreshed Meta Data.4. Interval Meta Data.5. Output Size  \
# 0         2024-11-15 19:55:00                  5min                  Compact
#
#   Meta Data.6. Time Zone Time Series (5min).2024-11-15 19:55:00.1. open  \
# 0             US/Eastern                                       225.1900
#
#   Time Series (5min).2024-11-15 19:55:00.2. high  \
# 0                                       225.2700
#
#   Time Series (5min).2024-11-15 19:55:00.3. low  \
# 0                                      225.1500
#
#   Time Series (5min).2024-11-15 19:55:00.4. close  ...  \
# 0                                        225.2700  ...
#
#   Time Series (5min).2024-11-15 11:45:00.1. open  \
# 0                                       225.1650
#
#   Time Series (5min).2024-11-15 11:45:00.2. high  \
# 0                                       225.3400
#
#   Time Series (5min).2024-11-15 11:45:00.3. low  \
# 0                                      225.1400
#
#   Time Series (5min).2024-11-15 11:45:00.4. close  \
# 0                                        225.2000
#
#   Time Series (5min).2024-11-15 11:45:00.5. volume  \
# 0                                           212126
#
#   Time Series (5min).2024-11-15 11:40:00.1. open  \
# 0                                       225.1694
#
#   Time Series (5min).2024-11-15 11:40:00.2. high  \
# 0                                       225.2300
#
#   Time Series (5min).2024-11-15 11:40:00.3. low  \
# 0                                      224.9800
#
#   Time Series (5min).2024-11-15 11:40:00.4. close  \
# 0                                        225.1500
#
#   Time Series (5min).2024-11-15 11:40:00.5. volume
# 0                                           188662
#
# [1 rows x 506 columns]

# %%
data
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2024-11-15 19:55:00',
#   '4. Interval': '5min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (5min)': {'2024-11-15 19:55:00': {'1. open': '225.1900',
#    '2. high': '225.2700',
#    '3. low': '225.1500',
#    '4. close': '225.2700',
#    '5. volume': '2375'},
#   '2024-11-15 19:50:00': {'1. open': '225.1900',
#    '2. high': '225.2000',
#    '3. low': '225.1500',
#    '4. close': '225.1800',
#    '5. volume': '1424'},
#   '2024-11-15 19:45:00': {'1. open': '225.2000',
#    '2. high': '225.2200',
#    '3. low': '225.1000',
#    '4. close': '225.1800',
#    '5. volume': '115'},
#   '2024-11-15 19:40:00': {'1. open': '225.2000',
#    '2. high': '225.2500',
#    '3. low': '225.1000',
#    '4. close': '225.1750',
#    '5. volume': '388'},
#   '2024-11-15 19:35:00': {'1. open': '225.2100',
#    '2. high': '225.2500',
#    '3. low': '225.1200',
#    '4. close': '225.1850',
#    '5. volume': '963'},
#   '2024-11-15 19:30:00': {'1. open': '225.0612',
#    '2. high': '225.2500',
#    '3. low': '225.0600',
#    '4. close': '225.1750',
#    '5. volume': '206'},
#   '2024-11-15 19:25:00': {'1. open': '225.2200',
#    '2. high': '225.2200',
#    '3. low': '225.0600',
#    '4. close': '225.1400',
#    '5. volume': '335'},
#   '2024-11-15 19:20:00': {'1. open': '225.0600',
#    '2. high': '225.2000',
#    '3. low': '225.0600',
#    '4. close': '225.1400',
#    '5. volume': '1615'},
#   '2024-11-15 19:15:00': {'1. open': '225.0400',
#    '2. high': '225.1900',
#    '3. low': '225.0300',
#    '4. close': '225.0700',
#    '5. volume': '3204'},
#   '2024-11-15 19:10:00': {'1. open': '225.0600',
#    '2. high': '225.0800',
#    '3. low': '225.0300',
#    '4. close': '225.0350',
#    '5. volume': '286'},
#   '2024-11-15 19:05:00': {'1. open': '225.0700',
#    '2. high': '225.0900',
#    '3. low': '225.0000',
#    '4. close': '225.0600',
#    '5. volume': '71085'},
#   '2024-11-15 19:00:00': {'1. open': '225.0600',
#    '2. high': '225.1000',
#    '3. low': '225.0300',
#    '4. close': '225.1000',
#    '5. volume': '139'},
#   '2024-11-15 18:55:00': {'1. open': '225.0800',
#    '2. high': '225.1300',
#    '3. low': '225.0300',
#    '4. close': '225.0400',
#    '5. volume': '1612'},
#   '2024-11-15 18:50:00': {'1. open': '225.1400',
#    '2. high': '225.1400',
#    '3. low': '225.0300',
#    '4. close': '225.0800',
#    '5. volume': '843'},
#   '2024-11-15 18:45:00': {'1. open': '225.1300',
#    '2. high': '225.1600',
#    '3. low': '225.0700',
#    '4. close': '225.1000',
#    '5. volume': '1017'},
#   '2024-11-15 18:40:00': {'1. open': '225.1500',
#    '2. high': '225.1600',
#    '3. low': '225.1000',
#    '4. close': '225.1600',
#    '5. volume': '281'},
#   '2024-11-15 18:35:00': {'1. open': '225.1600',
#    '2. high': '225.1700',
#    '3. low': '225.1000',
#    '4. close': '225.1300',
#    '5. volume': '946'},
#   '2024-11-15 18:30:00': {'1. open': '225.1900',
#    '2. high': '225.2000',
#    '3. low': '225.0800',
#    '4. close': '225.1200',
#    '5. volume': '1407'},
#   '2024-11-15 18:25:00': {'1. open': '225.0800',
#    '2. high': '225.2000',
#    '3. low': '225.0700',
#    '4. close': '225.1400',
#    '5. volume': '1421'},
#   '2024-11-15 18:20:00': {'1. open': '225.0400',
#    '2. high': '225.1300',
#    '3. low': '225.0400',
#    '4. close': '225.0400',
#    '5. volume': '756'},
#   '2024-11-15 18:15:00': {'1. open': '225.0800',
#    '2. high': '225.1300',
#    '3. low': '225.0300',
#    '4. close': '225.0850',
#    '5. volume': '585'},
#   '2024-11-15 18:10:00': {'1. open': '225.1100',
#    '2. high': '225.1300',
#    '3. low': '225.0300',
#    '4. close': '225.0800',
#    '5. volume': '668'},
#   '2024-11-15 18:05:00': {'1. open': '225.0700',
#    '2. high': '225.1000',
#    '3. low': '225.0400',
#    '4. close': '225.0850',
#    '5. volume': '1515'},
#   '2024-11-15 18:00:00': {'1. open': '225.0758',
#    '2. high': '225.1000',
#    '3. low': '225.0400',
#    '4. close': '225.0700',
#    '5. volume': '408'},
#   '2024-11-15 17:55:00': {'1. open': '225.0901',
#    '2. high': '225.1000',
#    '3. low': '225.0600',
#    '4. close': '225.0750',
#    '5. volume': '578'},
#   '2024-11-15 17:50:00': {'1. open': '225.0600',
#    '2. high': '225.1000',
#    '3. low': '225.0300',
#    '4. close': '225.0950',
#    '5. volume': '4474'},
#   '2024-11-15 17:45:00': {'1. open': '225.0300',
#    '2. high': '225.0900',
#    '3. low': '225.0100',
#    '4. close': '225.0400',
#    '5. volume': '842'},
#   '2024-11-15 17:40:00': {'1. open': '225.0300',
#    '2. high': '225.0300',
#    '3. low': '225.0100',
#    '4. close': '225.0100',
#    '5. volume': '984'},
#   '2024-11-15 17:35:00': {'1. open': '225.0300',
#    '2. high': '225.0300',
#    '3. low': '225.0100',
#    '4. close': '225.0200',
#    '5. volume': '318'},
#   '2024-11-15 17:30:00': {'1. open': '225.0200',
#    '2. high': '225.0300',
#    '3. low': '225.0100',
#    '4. close': '225.0300',
#    '5. volume': '516'},
#   '2024-11-15 17:25:00': {'1. open': '225.0150',
#    '2. high': '225.0300',
#    '3. low': '225.0000',
#    '4. close': '225.0200',
#    '5. volume': '12036'},
#   '2024-11-15 17:20:00': {'1. open': '225.0400',
#    '2. high': '225.0500',
#    '3. low': '225.0100',
#    '4. close': '225.0200',
#    '5. volume': '1116'},
#   '2024-11-15 17:15:00': {'1. open': '225.0200',
#    '2. high': '225.0500',
#    '3. low': '225.0112',
#    '4. close': '225.0400',
#    '5. volume': '652'},
#   '2024-11-15 17:10:00': {'1. open': '225.0300',
#    '2. high': '225.0800',
#    '3. low': '225.0100',
#    '4. close': '225.0300',
#    '5. volume': '3284'},
#   '2024-11-15 17:05:00': {'1. open': '225.0300',
#    '2. high': '225.0600',
#    '3. low': '225.0000',
#    '4. close': '225.0375',
#    '5. volume': '551783'},
#   '2024-11-15 17:00:00': {'1. open': '213.7986',
#    '2. high': '225.0500',
#    '3. low': '213.7986',
#    '4. close': '225.0200',
#    '5. volume': '9770'},
#   '2024-11-15 16:55:00': {'1. open': '225.0200',
#    '2. high': '225.0400',
#    '3. low': '213.7986',
#    '4. close': '225.0100',
#    '5. volume': '6440'},
#   '2024-11-15 16:50:00': {'1. open': '225.0250',
#    '2. high': '230.3802',
#    '3. low': '225.0000',
#    '4. close': '225.0200',
#    '5. volume': '167351'},
#   '2024-11-15 16:45:00': {'1. open': '225.0150',
#    '2. high': '230.3802',
#    '3. low': '225.0000',
#    '4. close': '225.0500',
#    '5. volume': '9332'},
#   '2024-11-15 16:40:00': {'1. open': '225.0200',
#    '2. high': '226.1250',
#    '3. low': '225.0000',
#    '4. close': '225.0000',
#    '5. volume': '60579'},
#   '2024-11-15 16:35:00': {'1. open': '225.0050',
#    '2. high': '225.0300',
#    '3. low': '225.0000',
#    '4. close': '225.0200',
#    '5. volume': '59113'},
#   '2024-11-15 16:30:00': {'1. open': '225.0000',
#    '2. high': '225.0300',
#    '3. low': '225.0000',
#    '4. close': '225.0100',
#    '5. volume': '3380'},
#   '2024-11-15 16:25:00': {'1. open': '225.0000',
#    '2. high': '231.4100',
#    '3. low': '225.0000',
#    '4. close': '225.0100',
#    '5. volume': '2786'},
#   '2024-11-15 16:20:00': {'1. open': '225.0000',
#    '2. high': '225.0300',
#    '3. low': '225.0000',
#    '4. close': '225.0100',
#    '5. volume': '2691'},
#   '2024-11-15 16:15:00': {'1. open': '225.0150',
#    '2. high': '225.0300',
#    '3. low': '225.0000',
#    '4. close': '225.0150',
#    '5. volume': '69429'},
#   '2024-11-15 16:10:00': {'1. open': '225.0400',
#    '2. high': '234.9083',
#    '3. low': '224.9700',
#    '4. close': '225.0150',
#    '5. volume': '32897'},
#   '2024-11-15 16:05:00': {'1. open': '225.0800',
#    '2. high': '234.9083',
#    '3. low': '225.0000',
#    '4. close': '225.0390',
#    '5. volume': '11744'},
#   '2024-11-15 16:00:00': {'1. open': '224.9200',
#    '2. high': '225.2005',
#    '3. low': '224.5660',
#    '4. close': '225.0600',
#    '5. volume': '22236107'},
#   '2024-11-15 15:55:00': {'1. open': '225.1400',
#    '2. high': '225.2300',
#    '3. low': '224.8600',
#    '4. close': '224.9200',
#    '5. volume': '1765398'},
#   '2024-11-15 15:50:00': {'1. open': '224.7600',
#    '2. high': '225.2500',
#    '3. low': '224.7550',
#    '4. close': '225.1200',
#    '5. volume': '972423'},
#   '2024-11-15 15:45:00': {'1. open': '224.7900',
#    '2. high': '224.8699',
#    '3. low': '224.5699',
#    '4. close': '224.7600',
#    '5. volume': '453735'},
#   '2024-11-15 15:40:00': {'1. open': '224.9050',
#    '2. high': '225.0600',
#    '3. low': '224.7250',
#    '4. close': '224.7900',
#    '5. volume': '399958'},
#   '2024-11-15 15:35:00': {'1. open': '224.9450',
#    '2. high': '225.0100',
#    '3. low': '224.8700',
#    '4. close': '224.9000',
#    '5. volume': '301225'},
#   '2024-11-15 15:30:00': {'1. open': '224.8100',
#    '2. high': '224.9600',
#    '3. low': '224.7500',
#    '4. close': '224.9500',
#    '5. volume': '345195'},
#   '2024-11-15 15:25:00': {'1. open': '224.9050',
#    '2. high': '224.9700',
#    '3. low': '224.8000',
#    '4. close': '224.8100',
#    '5. volume': '270491'},
#   '2024-11-15 15:20:00': {'1. open': '225.0650',
#    '2. high': '225.1900',
#    '3. low': '224.8350',
#    '4. close': '224.9050',
#    '5. volume': '289991'},
#   '2024-11-15 15:15:00': {'1. open': '224.8745',
#    '2. high': '225.1400',
#    '3. low': '224.8701',
#    '4. close': '225.0700',
#    '5. volume': '337087'},
#   '2024-11-15 15:10:00': {'1. open': '224.9300',
#    '2. high': '225.0400',
#    '3. low': '224.8500',
#    '4. close': '224.8750',
#    '5. volume': '349653'},
#   '2024-11-15 15:05:00': {'1. open': '225.1750',
#    '2. high': '225.3100',
#    '3. low': '224.8250',
#    '4. close': '224.9200',
#    '5. volume': '390942'},
#   '2024-11-15 15:00:00': {'1. open': '224.8250',
#    '2. high': '225.1900',
#    '3. low': '224.8000',
#    '4. close': '225.1750',
#    '5. volume': '307875'},
#   '2024-11-15 14:55:00': {'1. open': '224.5000',
#    '2. high': '224.8282',
#    '3. low': '224.5000',
#    '4. close': '224.8250',
#    '5. volume': '163155'},
#   '2024-11-15 14:50:00': {'1. open': '224.7630',
#    '2. high': '224.8100',
#    '3. low': '224.4700',
#    '4. close': '224.5000',
#    '5. volume': '195255'},
#   '2024-11-15 14:45:00': {'1. open': '224.8300',
#    '2. high': '224.9500',
#    '3. low': '224.7600',
#    '4. close': '224.7700',
#    '5. volume': '200148'},
#   '2024-11-15 14:40:00': {'1. open': '224.5100',
#    '2. high': '224.9300',
#    '3. low': '224.4800',
#    '4. close': '224.8400',
#    '5. volume': '290546'},
#   '2024-11-15 14:35:00': {'1. open': '224.4500',
#    '2. high': '224.6100',
#    '3. low': '224.4401',
#    '4. close': '224.5000',
#    '5. volume': '144711'},
#   '2024-11-15 14:30:00': {'1. open': '224.4000',
#    '2. high': '224.5800',
#    '3. low': '224.3000',
#    '4. close': '224.4550',
#    '5. volume': '219957'},
#   '2024-11-15 14:25:00': {'1. open': '224.5500',
#    '2. high': '224.5727',
#    '3. low': '224.3300',
#    '4. close': '224.3999',
#    '5. volume': '168841'},
#   '2024-11-15 14:20:00': {'1. open': '224.6800',
#    '2. high': '224.6900',
#    '3. low': '224.4900',
#    '4. close': '224.5600',
#    '5. volume': '191371'},
#   '2024-11-15 14:15:00': {'1. open': '224.6750',
#    '2. high': '224.7600',
#    '3. low': '224.6000',
#    '4. close': '224.6859',
#    '5. volume': '154699'},
#   '2024-11-15 14:10:00': {'1. open': '224.7650',
#    '2. high': '224.8000',
#    '3. low': '224.5700',
#    '4. close': '224.6600',
#    '5. volume': '618877'},
#   '2024-11-15 14:05:00': {'1. open': '224.6950',
#    '2. high': '224.9600',
#    '3. low': '224.6600',
#    '4. close': '224.7650',
#    '5. volume': '198317'},
#   '2024-11-15 14:00:00': {'1. open': '224.6700',
#    '2. high': '224.7950',
#    '3. low': '224.6400',
#    '4. close': '224.6790',
#    '5. volume': '181257'},
#   '2024-11-15 13:55:00': {'1. open': '224.6500',
#    '2. high': '224.6699',
#    '3. low': '224.4500',
#    '4. close': '224.6650',
#    '5. volume': '217378'},
#   '2024-11-15 13:50:00': {'1. open': '224.5200',
#    '2. high': '224.6550',
#    '3. low': '224.5100',
#    '4. close': '224.6500',
#    '5. volume': '164542'},
#   '2024-11-15 13:45:00': {'1. open': '224.7600',
#    '2. high': '224.7700',
#    '3. low': '224.5112',
#    '4. close': '224.5112',
#    '5. volume': '172632'},
#   '2024-11-15 13:40:00': {'1. open': '224.8087',
#    '2. high': '224.8100',
#    '3. low': '224.6700',
#    '4. close': '224.7500',
#    '5. volume': '148534'},
#   '2024-11-15 13:35:00': {'1. open': '224.5400',
#    '2. high': '224.8500',
#    '3. low': '224.5200',
#    '4. close': '224.8050',
#    '5. volume': '670742'},
#   '2024-11-15 13:30:00': {'1. open': '224.7200',
#    '2. high': '224.7500',
#    '3. low': '224.5500',
#    '4. close': '224.5500',
#    '5. volume': '203854'},
#   '2024-11-15 13:25:00': {'1. open': '224.5900',
#    '2. high': '224.8600',
#    '3. low': '224.5800',
#    '4. close': '224.7350',
#    '5. volume': '164631'},
#   '2024-11-15 13:20:00': {'1. open': '224.7000',
#    '2. high': '224.9500',
#    '3. low': '224.5364',
#    '4. close': '224.5900',
#    '5. volume': '244558'},
#   '2024-11-15 13:15:00': {'1. open': '224.6400',
#    '2. high': '224.8600',
#    '3. low': '224.6300',
#    '4. close': '224.6900',
#    '5. volume': '176076'},
#   '2024-11-15 13:10:00': {'1. open': '224.7400',
#    '2. high': '224.7500',
#    '3. low': '224.6077',
#    '4. close': '224.6400',
#    '5. volume': '801429'},
#   '2024-11-15 13:05:00': {'1. open': '224.6300',
#    '2. high': '224.8100',
#    '3. low': '224.4800',
#    '4. close': '224.7500',
#    '5. volume': '217395'},
#   '2024-11-15 13:00:00': {'1. open': '224.7350',
#    '2. high': '224.8500',
#    '3. low': '224.6100',
#    '4. close': '224.6101',
#    '5. volume': '290580'},
#   '2024-11-15 12:55:00': {'1. open': '224.4000',
#    '2. high': '224.7950',
#    '3. low': '224.4000',
#    '4. close': '224.7300',
#    '5. volume': '248813'},
#   '2024-11-15 12:50:00': {'1. open': '224.6000',
#    '2. high': '224.6000',
#    '3. low': '224.2700',
#    '4. close': '224.4000',
#    '5. volume': '1286410'},
#   '2024-11-15 12:45:00': {'1. open': '224.6950',
#    '2. high': '224.8200',
#    '3. low': '224.5800',
#    '4. close': '224.6100',
#    '5. volume': '215282'},
#   '2024-11-15 12:40:00': {'1. open': '224.6001',
#    '2. high': '224.7000',
#    '3. low': '224.4400',
#    '4. close': '224.7000',
#    '5. volume': '225506'},
#   '2024-11-15 12:35:00': {'1. open': '224.7300',
#    '2. high': '224.7500',
#    '3. low': '224.4900',
#    '4. close': '224.6100',
#    '5. volume': '238534'},
#   '2024-11-15 12:30:00': {'1. open': '224.8700',
#    '2. high': '224.8800',
#    '3. low': '224.7338',
#    '4. close': '224.7338',
#    '5. volume': '170740'},
#   '2024-11-15 12:25:00': {'1. open': '224.8900',
#    '2. high': '224.9900',
#    '3. low': '224.8400',
#    '4. close': '224.8724',
#    '5. volume': '174132'},
#   '2024-11-15 12:20:00': {'1. open': '225.0100',
#    '2. high': '225.1800',
#    '3. low': '224.8200',
#    '4. close': '224.8850',
#    '5. volume': '366327'},
#   '2024-11-15 12:15:00': {'1. open': '224.9950',
#    '2. high': '225.1700',
#    '3. low': '224.8605',
#    '4. close': '225.0000',
#    '5. volume': '215610'},
#   '2024-11-15 12:10:00': {'1. open': '224.9000',
#    '2. high': '225.0000',
#    '3. low': '224.7700',
#    '4. close': '224.9950',
#    '5. volume': '277414'},
#   '2024-11-15 12:05:00': {'1. open': '224.9000',
#    '2. high': '224.9600',
#    '3. low': '224.6700',
#    '4. close': '224.9000',
#    '5. volume': '242138'},
#   '2024-11-15 12:00:00': {'1. open': '225.1000',
#    '2. high': '225.1000',
#    '3. low': '224.8400',
#    '4. close': '224.8950',
#    '5. volume': '234269'},
#   '2024-11-15 11:55:00': {'1. open': '225.4700',
#    '2. high': '225.4800',
#    '3. low': '225.0400',
#    '4. close': '225.1000',
#    '5. volume': '426602'},
#   '2024-11-15 11:50:00': {'1. open': '225.1900',
#    '2. high': '225.4800',
#    '3. low': '225.1900',
#    '4. close': '225.4700',
#    '5. volume': '253061'},
#   '2024-11-15 11:45:00': {'1. open': '225.1650',
#    '2. high': '225.3400',
#    '3. low': '225.1400',
#    '4. close': '225.2000',
#    '5. volume': '212126'},
#   '2024-11-15 11:40:00': {'1. open': '225.1694',
#    '2. high': '225.2300',
#    '3. low': '224.9800',
#    '4. close': '225.1500',
#    '5. volume': '188662'}}}
